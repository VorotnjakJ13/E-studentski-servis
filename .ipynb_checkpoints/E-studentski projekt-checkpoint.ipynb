# %%
# -*- coding: utf-8 -*-

# %%
from bs4 import BeautifulSoup
import requests 
import re
import csv
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
url = 'https://www.studentski-servis.com/index.php?t=prostaDela&hp=true&page=1&perPage=3016&sort=1&workType=1&keyword='
       
url_data=requests.get(url).content

soup = BeautifulSoup(url_data,'html.parser')

# %%
# SEZNAMI:
jobs = soup.findAll('div',{'class':'jobItem'})
ime = soup.findAll('span', {'class':'title'})
placa = soup.findAll('span',{'class':'postavka'})
lokacija = soup.findAll('span',{'class':'lokacija'})
opis = soup.findAll('div',{'class':'jobContent col'})
opiss= soup.findAll('p')
sifre=[]
for i in range(len(jobs)):
    sifra = jobs[i].li.parent.li.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling
    sifre.append(sifra.text.strip('Šifra: ').strip(' |'))



dataset= [(s,i.text.strip('\n'),p.text.strip('\n').strip('\r\n\t\t\t\t\t').replace(',','.'),l.text.strip('\n'),op.text.replace('|\n','. ').replace('\n','').replace('\r','')) for s,i,p,l,op in zip( sifre,ime,placa,lokacija,opis)]

# %%
with open('estudent.csv','w+',encoding='utf-8') as csvfile: 
    writer = csv.writer(csvfile)
    writer.writerow(['sifra','naziv','placa','lokacija','opis'])
    for tuple in dataset:
        if tuple[0] is csvfile.read():
            None
        else:
            writer.writerow(tuple)

# %%
data=pd.read_csv('estudent.csv')
pd.options.display.max_rows = 20
data['neto']=data['placa']

vzorec_neto = re.compile(r"(?P<neto>.*?) €\/h neto",flags=re.DOTALL)

vrednosti=[]
for i in range(len(data['neto'])):
    if re.findall(vzorec_neto,data['neto'][i]):
        vrednosti+=re.findall(vzorec_neto,data['neto'][i])
    else: vrednosti.append('0')
vrednosti
data['neto']=vrednosti
data['neto']=pd.to_numeric(data.neto)
data
# Out:
#       sifra                  naziv                             placa  \
# 0    321378                STREŽBA    4.65 €/h neto (5.50 €/h bruto)
# 1    321377      POMOČ PRI PRODAJI    4.56 €/h neto (5.40 €/h bruto)
# 2    321376  PRODAJAPRIPRAVA HRANE    4.56 €/h neto (5.40 €/h bruto)
# 3    321375      POMOČ PRI PRODAJI    4.56 €/h neto (5.40 €/h bruto)
# 4    321374                 RAZVOZ    4.56 €/h neto (5.40 €/h bruto)
# ..      ...                    ...                               ...
# 992  275186          PROGRAMIRANJE           PO DOGOVORU/PROJEKTU...
# 993  270843                TRŽENJE  10.00 €/h neto (11.83 €/h bruto)
# 994  270842                TRŽENJE  10.00 €/h neto (11.83 €/h bruto)
# 995  270841                TRŽENJE  10.00 €/h neto (11.83 €/h bruto)
# 996  270835                TRŽENJE  10.00 €/h neto (11.83 €/h bruto)
#
#                     lokacija  \
# 0                     KAMNIK
# 1                       PTUJ
# 2                      CELJE
# 3    BREZOVICA PRI LJUBLJANI
# 4                      CELJE
# ..                       ...
# 992                LJUBLJANA
# 993                DOLENJSKA
# 994                ŠTAJERSKA
# 995      LJUBLJANA Z OKOLICO
# 996                GORENJSKA
#
#                                                   opis   neto
# 0    Iščejo polnoletni osebi za delo v strežbi. Pre...   4.65
# 1    Podjetje potrebuje polnoletni, zanesljivi, ves...   4.56
# 2    Prodaja kruha in peciva ter izdelava sendvičev...   4.56
# 3    Podjetje išče več polnoletnih oseb za pomoč pr...   4.56
# 4    Razvoz in dostava blaga s kombijem na območju ...   4.56
# ..                                                 ...    ...
# 992  Zaželeno poznavanje: PL/SQL, JAVASCRIPT, C,C++...   0.00
# 993  Promocija in trženje pri vnaprej dogovorjenih ...  10.00
# 994  Promocija in trženje pri vnaprej dogovorjenih ...  10.00
# 995  Promocija in trženje pri vnaprej dogovorjenih ...  10.00
# 996  Promocija in trženje pri vnaprej dogovorjenih ...  10.00
#
# [997 rows x 6 columns]

# %%
df=data[['sifra','naziv','lokacija','neto']]
coredf=df[df.neto !=0] #izbrisali smo vse sluzbe ki nimajo podane neto plače
coredf
# Out:
#       sifra                  naziv                 lokacija   neto
# 0    321378                STREŽBA                   KAMNIK   4.65
# 1    321377      POMOČ PRI PRODAJI                     PTUJ   4.56
# 2    321376  PRODAJAPRIPRAVA HRANE                    CELJE   4.56
# 3    321375      POMOČ PRI PRODAJI  BREZOVICA PRI LJUBLJANI   4.56
# 4    321374                 RAZVOZ                    CELJE   4.56
# ..      ...                    ...                      ...    ...
# 990  286805           FIZIČNA DELA                 RADOMLJE   4.65
# 993  270843                TRŽENJE                DOLENJSKA  10.00
# 994  270842                TRŽENJE                ŠTAJERSKA  10.00
# 995  270841                TRŽENJE      LJUBLJANA Z OKOLICO  10.00
# 996  270835                TRŽENJE                GORENJSKA  10.00
#
# [890 rows x 4 columns]

# %%
# stevilo oglasov po mestih
po_mestih=coredf.groupby('lokacija')['naziv'].count()
#enako : coredf.groupby('lokacija').size()
po_mestih=pd.to_numeric(po_mestih)
po_mestih
# Out:
# lokacija
# ADLEŠIČI                 1
# ALEJA LJUBLJANA-ŠIŠKA    1
# ANAKRAN                  2
# ANKARAN                  2
# APAČE                    2
#                         ..
# ŠMARTNO PRI LITIJI       4
# ŠTAJERSKA                1
# ŽEJE PRI KOMENDI         1
# ŽUSTERNA                 1
# ŽUŽEMBERK                3
# Name: naziv, Length: 321, dtype: int64

# %%
po_mestih_po_placah=coredf.groupby('lokacija')['neto'].agg(['sum','count','min','max'])

# %%
#povprečna plača po krajih
povp_po_mestih= round(coredf.groupby('lokacija')['neto'].mean(),2)
povp_po_mestih = pd.DataFrame({'povp neto' : povp_po_mestih}).reset_index()
povp_po_mestih
# Out:
#                   lokacija  povp neto
# 0                 ADLEŠIČI       5.50
# 1    ALEJA LJUBLJANA-ŠIŠKA       5.50
# 2                  ANAKRAN       5.75
# 3                  ANKARAN       6.25
# 4                    APAČE       7.00
# ..                     ...        ...
# 316     ŠMARTNO PRI LITIJI       5.00
# 317              ŠTAJERSKA      10.00
# 318       ŽEJE PRI KOMENDI       5.07
# 319               ŽUSTERNA       6.00
# 320              ŽUŽEMBERK       4.71
#
# [321 rows x 2 columns]

# %%
povp_po_mestih.plot(x='lokacija', y='povp neto', kind = 'line', figsize=(20,5))
# z plotly knjižnjico bi lahko imeli interaktivni graf inbi lahko pogledali po grafu .. meni žal ne dela

# %%
#povprecne place po delih, po mestih , nad 5 eur neto.
b= coredf[coredf.neto>5]
bb=round(b.groupby(['lokacija','naziv'])['neto'].mean(),2)

bb = pd.DataFrame({'povp neto' : bb}).reset_index() #naredimo nov DataFrame, da lahko rišemo grafe
#bb.sort_values('povp neto', axis=0)
bb
# Out:
#                   lokacija                                 naziv  povp neto
# 0                 ADLEŠIČI               STREŽBA HRANE IN PIJAČE       5.50
# 1    ALEJA LJUBLJANA-ŠIŠKA                               STREŽBA       5.50
# 2                  ANAKRAN              POMOČ V KUHINJIPOMIVALEC       5.50
# 3                  ANAKRAN              STREŽBADELO NA RECEPCIJI       6.00
# 4                  ANKARAN                       POMOČ V STREŽBI       6.00
# ..                     ...                                   ...        ...
# 353             ŠMARJE SAP                       POMOČ V STREŽBI       6.00
# 354        ŠMARTNO OB PAKI              STROKOVNO DELOTESTIRANJE       5.50
# 355              ŠTAJERSKA                               TRŽENJE      10.00
# 356       ŽEJE PRI KOMENDI  LAŽJA FIZIČNA DELADELO V PROIZVODNJI       5.07
# 357               ŽUSTERNA                               STREŽBA       6.00
#
# [358 rows x 3 columns]

# %%
#bb.plot(x='naziv',y='povp neto')

# %%
c=coredf[coredf.eq('PROGRAMIRANJE').any(1)]#po stolpcih izložimo vse ki niso 'PROGRAMIRANJE'
c[c.eq('LJUBLJANA').any(1)] # vse programerske službe v ljubljani ('LJUBLJANA')
# Out:
#       sifra          naziv   lokacija   neto
# 351  320532  PROGRAMIRANJE  LJUBLJANA  13.00
# 738  318094  PROGRAMIRANJE  LJUBLJANA   9.00
# 805  317660  PROGRAMIRANJE  LJUBLJANA   8.70
# 888  316853  PROGRAMIRANJE  LJUBLJANA  10.00
# 890  316770  PROGRAMIRANJE  LJUBLJANA   9.00
# 891  316740  PROGRAMIRANJE  LJUBLJANA   7.15
# 902  315583  PROGRAMIRANJE  LJUBLJANA  12.00
# 920  313512  PROGRAMIRANJE  LJUBLJANA   6.40
# 927  313057  PROGRAMIRANJE  LJUBLJANA   7.61
# 988  287388  PROGRAMIRANJE  LJUBLJANA   7.00
